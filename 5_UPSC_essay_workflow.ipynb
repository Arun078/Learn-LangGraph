# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator

from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
groq_api_key = os.getenv("GROQ_API_KEY")

llm_model = ChatGroq(
temperature=0.4, 
model="llama-3.3-70b-versatile",
api_key=groq_api_key
)

# %%
#llama-3.3-70b-versatile openai/gpt-oss-1206

#create a schema for evaluation
class EvaluationSchema(BaseModel):
    feedback: str = Field(description="Detailed Feedback for the essay")
    score: int = Field(description="Score given to essay out of 10 in integer form", ge=0, le=10)

structured_model = llm_model.with_structured_output(EvaluationSchema)

# %%
essay = """Introduction:

India is undergoing a remarkable transformation in Artificial Intelligence, driven by the visionary leadership of PM Rodi. For the first time in India's history, the government is actively shaping an Az ecosysten where computing power, GPUs, and research opportunities are accessible at an affordable cost.

Unlike in the past, Al in India is no longer confined to a privileged few or dominated by global tech giants. Through forward-looking policies, the Nodi government is empowering students, startups, and innovators with world-class AI Infrastructure, fostering a truly level playing field. Initiatives such as the IndiaAl Rission and the establishment of Centres of Excellence for Al are strengthening the country's At ecosystem, paving the way for innovation and self-reliance in this critical sector.

These efforts align with the vision of Viksit Bharet by 2847, where India aspires to become a global Al powerhouse, leveraging cutting-edge technology for economic growth, governance, and societal progress.

AI Compute and Semiconductor Infrastructure:

India is rapidly building a strong Al computing and semiconductor infrastructure to support its growing digital economy. With the approval of the IndiaAl Rission in 2824, the government allocated 10,300 crore over five years to strengthen Al capabilities. A key focus of this mission is the development of a high-end common computing facility equipped with 18,683 Graphics Processing Units (GPUs), making it one of the most extensive Al compute infrastructures globally. This capacity is nearly nine times that of the open-source AX model DeepSeek and about two-thirds of what ChatOPT operates on.

Here are the key developments:

Scaling AI Compute Infrastructure: The initial phase of the mission has already nada 10,000 GPUs available, with the ramaining units to be added soon. This will enable the creation of indigenous Al solutions tailored to Indian languages and contexts.

Opening Access to High-Performance Computing: India has also pioneered the launch of an open GPU marketplace, making high-performance computing accessible to startups, researchers, and students. Unlike many countries where AI infrastructure is controlled by large corporations, this initiative ensures that small players have an opportunity to Innovata.

Robust GPU Supply Chain: The government has selected 18 companies to supply the GPUs, ensuring a robust and diversified supply chain.

Indigenous GPU Capabilities: To further strengthen domestic capabilities, India aims to develop its cum GPU within the next three to five years, reducing reliance on imported technology.

Affordable Compute Access: A new common computa facility will soon be launched, allowing researchers and startups to access GPU power at a highly subsidised rate of 100 per hour, compared to the global cost of $2.5 to $3 per hour. Strengthening Semiconductor Manufacturing: In parallel, India is advancing samiconductor manufacturing, with five semiconductor plants under construction. These developments will not only support Al Innovation but also reinforce Indians position in the global electronics sector.

Advancing AI with Open Data and Centres of Excellance (Coll):

Recognising the importance of data in Al development, the Rodi government has launched the IndiaAl Dataset Platform to provide seamless access to high-quality, non-personal datasets. This platform will house the largest collection of anonymised data, empowering Indian startups and researchers to develop advanced Al applications. By ensuring diverse and abundant datasets, this initiative will drive Al-driven solutions across key sectors, enhancing innovation and accuracy.

IndiaAI Dataset Platform for Open Data Access: The platform will enable Indian startups and researchers to access a smified repository of high-quality, anonymised datasets, reducing barriers to Al innovation.

Boosting AT Rodel Accuracy with Diverse Data: By providing large-scale, non-personal datasets, the initiative will help reduce biases and improve the reliability of Al applications across domains such as agriculture, weather forecasting, and traffic management.

Centres of Excellence: The government has established three Al Centres of Excellence (CoE) in Healthcare, Agriculture, and Sustainable Cities in New Delhi. The Budget 2825 further announced a new CoE for AI in education with an outlay of 4500 crore, making it the fourth such centre.

Skilling for AI-Driven Industries: Plans are in place for five National Centres of Excellence for Skilling, which will equip youth with industry-relevant expertise. These centres will be set up in collaboration with global partners to support the take for India, Naks for the World vision in manufacturing and Az innovation.

Indias At Nodels à Language Technologies:

The government is facilitating the development of Indias own foundational models, including Large Language Models (LLits) and problem-specific Al solutions tailored to Indian needs. To foster Al research, multiple Centres of Excellence have also been set up.

Indlas Foundational Large Language Rodels: 
IndiaAz has launched an initiative to develop indigenous foundational models, including Lits and Small Language Nodels (SLAs), through a call for proposals. Digital India BHASHINE: An AX-led language translation platform designed to enable easy access to the internet and digital services in Indian languages, including voice-based access, and support content creation in Indian languages. Bharatßen: The world first government-funded multimodal LUR initiative, Bharatden was launched in 2024 in Delhi. It ains to enhance public service delivery and citizen engagement through foundational models in language, speech, and computer vision. Sharetsen involves a consortium of At researchers from premier academic institutions in India. Sarvan-1 Al Rodel: A large language model optimized for Indian languages, Sarvan-1 hes 2 billion parameters and supports ten sajor Indian languages. It is designed for applications such as language translation, text summarisation, and contant generation.

Chitralekha: An open-source video transcreation platform developed by AZ4ähäret, Chitralekha enables users to generate and edit audio transcripts in various Indic languages.

Hanocnars Everest 1.0: A multilingual Al systen developed by SAL, Everest 1.0 supports 35 Indian languages, with plans to expand to 50.

AI Integration with Digital Public Infrastructure:

Indians Digital Public Infrastructure (DPI) has redefined digital innovation by combining public funding with private sector-led innovation. Platforms lika Aadhaar, UPI, and DigiLocker serve as the foundation, while private entities build application-specific solutions on top of thes. This model is now being anhanced with AZ, integrating intelligent solutions into financial and governance platforms. The global appeal of India's DPI was evident at the 620 Summit, where several countries expressed interest in adopting similar frameworks. Japens patent grant to Indias UPI payment systen further underscores its scalability.

For Mahakumbh 2925, AI-driven DPI solutions played a crucial role in managing the world's largest human gathering. AI-powered tools monitored real-time railway passenger movement to optimise crowd dispersal in Prayagraj. The Bhashini-powered Kumbh sahAyak Chatbot enabled voice-based lost-and-found services, real-time translation, and multilingual assistance. Its integration with Indian Railways and UP Police streamlined communication, ensuring swift issue resolution. By leveraging Al with DPZ, Mahakumbh 2925 set a global benchmark for tech-enabled, inclusive, and efficient event management.

AI Talent & Morkforce Development:

Indias workforce is at the heart of its digital revolution. The country is adding one Global Capability Center (GCC) every week, reinforcing its status as a preferred destination for global AED and technological development. However, sustaining this growth will require continuous investment in education and skill development. The government is addressing this challange by revamping university curricula to include AI, 56, and semiconductor design, aligning with the National Education Policy (NEP) 2020. This ensures that gradustes acquire job-ready skills, reducing the transition time between education and employment.

Al Talent Pipeline & At Education: Under the IndiaAI Future Skills initiative, Al education is being expanded across undergraduate, postgraduate, and Ph.D. programs. Fellowships are being provided to full-time Ph.D. scholars researching AI in the top 50 HIRF-ranked institutes. To enhance accessibility, Data and AI Labs are being established in Ther 2 and Tier 3 cities, with a model IndiaAl Deta Lab already set up at NIELIT Delhi.

India Ranks ist in Global At Skill Penetration: According to the Stanford AZ Index 2024, India ranks first globally in AI skill penstration with a score of 2.8, ahead of the US (2.2) and Germany (1.9). AI talent concentration in India has grown by 263% since 2016, positioning the country as a major Al hub. India also leads in At Skill Penetration for

Momen, with a score of 1.7, surpassing the US (1.2) and Israel (0.9). AI Innovation: India has emerged as the fastest-growing developer population globally and ranks second in public generative Al projects on Github. The country is home to 16% of the worlds AI talent, showcasing its growing influence in Al innovation and adoption. 

AI Talent Hubs: The India Skills Report 2024 by heebox forecasts that Indias Al industry will reach USD 28.8 billion by 2025, with a CAGR of 45%. The AI-skilled workforce has seen a 14-fold increase from 2016 to 2023, making India one of the top five fastest-growing Al talent hubs, alongside Singapore, Finland, Ireland, and Canada. The demand for AI professionals in India is projected to reach 1 million by 2026.

AI Adoption & Industry Growth:

India's Generative AX (GenAI) ecosysten has seen remarkable growth, even amid a global downturn. The country's AI landscape is evolving from experimental use cases to scalable, production-ready solutions, reflecting its growing maturity.

Businesses Prioritising Al Investments: According to BCS, 80% of Indian companies consider Al a core strategic priority, surpassing the global average of 75%. Additionally, 69% plan to increase their tech investments in 2025, with one-third allocating over USD 25 million to Al initiatives.

GenAI Startup Funding: According to a November 2024 report by National Association of Software and Service Companies

(NASSCON), Indian GenAI startup funding surged over six times quarter-on-quarter, reaching USD 51 million in Q2FY2025, driven by 828 and agentic Al startups.

AI Transforming Morkplaces: The Randstad AI & Equity Report 2024 states that seven in 10 Indian employees used AX at work in 2024, up from five in 10 year earlier, showcasing As rapid integration into workplaces.

AZ Expowering Small & Medium Businesses (SHBs): AI-driven technologies, such as autonomous agents, are helping Sis scale efficiently, personalise customer experiences, and optimise operations. According to Salesforce, 78% of Indian SPBs using Al reported revenue growth, while 93% stated Al has contributed to increased revenues. Rapid Expansion of India's Al Economy: As per the BCG-NASSCOM Report 2024, Indias Al market is projected to grow at CAGR of 25-35%, reinforcing its potential for innovation and job creation. While Al automates routine tasks, it is simultaneously generating new opportunities in data science, machine learning, and Al-driven applications. AI Startup Support Ecosystes: India hosts 520+ tech incubators and accelerators, ranking third globally in active programs. 42% of these were established in the past five years, catering to the evolving needs of Indian startups. AI-focused accelerators like T-Hub NATH provide crucial mentorship in product development, business strategy, and scaling. In early 2024, MATH supported over 60 startups, with five actively discussing funding, highlighting India's growing AI startup landscape.

A Pragmatic AL Regulation Approach:

Indias pragmatic Al regulation balances innovation and accountability, steering clear of overregulation that could stifle growth and unchecked market-driven governance that may create monopolies. Instead of relying solely on legislation, India is investing in Al-driven safeguards, funding top universities and IITs to develop solutions for deep fakes, privacy risks, and cybersecurity threats. This techno-legal approach ensures Al remains a force for inclusive growth, fostering an ecosystem where innovation thrives while ethical concerns are proactively addressed.

Conclusion:

India's rapid advancements in artificial intelligence, underpinned by strategic government initiatives, have positioned the country as a global Al powerhouse. By expanding Al compute infrastructure, fostering indigenous Al models, enhancing digital public infrastructure, and investing in talent development, India is creating an inclusive and innovation-driven ecosystem. The emphasis on open data, affordable access to high-performance computing, and AI-driven solutions tailored to local needs ensures that the benefits of Al reach businesses, researchers, and citizens alike. As AT adoption accelerates across industries, India's proactive approach is not only strengthening its digital economy but also paving the way for self-reliance in critical technologies, with a clear vision for the future, India is set to become a leader in Al innovation, shaping the global Al landscape in the years to come. """

# %%
prompt = f"""You are an expert essay evaluator. Provide detailed feedback and a score out of 10 for the following essay based on the following criteria:

1. Clarity and coherence of ideas
2. Depth of analysis and insight
3. Use of evidence and examples
4. Overall-structure and organization
5. Language and style 

{essay}""" 

structured_model.invoke(prompt)
# Out:
# EvaluationSchema(feedback="The essay provides a comprehensive overview of India's transformation in Artificial Intelligence, driven by the government's visionary leadership and forward-looking policies. The writer effectively highlights the country's efforts to build a strong AI computing and semiconductor infrastructure, develop indigenous AI models, and foster a level playing field for innovation. The essay also explores the importance of open data, affordable access to high-performance computing, and AI-driven solutions tailored to local needs. The writer demonstrates a good understanding of the subject matter, providing relevant examples and statistics to support their arguments. However, the essay could benefit from more critical analysis and depth of insight, as well as more nuanced language and style. Additionally, the writer could have provided more concrete recommendations for future development and addressed potential challenges and limitations. Overall, the essay is well-s
# ...

# %%
prompt = f"Evaluate the language quality of the following essay and provide feedback and assign a score out of 10\n {essay}."

structured_model.invoke(prompt).feedback
# Out:
# "The essay demonstrates a good understanding of India's advancements in artificial intelligence, with a clear and well-structured narrative. However, there are some areas that require improvement, such as the use of proper nouns (e.g., 'Rodi' instead of 'Modi'), grammatical errors, and inconsistencies in formatting. Additionally, the essay could benefit from more precise and concise language, as some sentences are overly long and convoluted. The use of transitional phrases and sentences could also be improved to enhance the flow of the essay. Overall, the essay provides a comprehensive overview of India's AI landscape, but requires refinement in terms of language quality and attention to detail."

# %%
#create a typed dict for the state
class UPSCState(TypedDict):
    essay:str
    language_feedback: str
    clarity_feedback: str
    analysis_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: UPSCState):
    prompt = f"Evaluate the language quality of the following essay and provide feedback and assign a score out of 10\n {state['essay']}"
    output = structured_model.invoke(prompt)
    return {"language_feedback": output.feedback, "individual_scores":[output.score]}

def evaluate_clarity(state: UPSCState):
    prompt = f"Evaluate the clarity of thought the following essay and provide feedback and assign a score out of 10\n {state['essay']}"
    output = structured_model.invoke(prompt)
    return {"clarity_feedback": output.feedback, "individual_scores": [output.score]}

def evaluate_analysis(state: UPSCState):
    prompt = f"Evaluate the depth of analysis of the following essay and provide feedback and assign a score out of 10 \n {state['essay'] }"
    output = structured_model.invoke(prompt)
    return {"analysis_feedback": output.feedback, "individual_scores": [output.score]}

def final_evaluation(state: UPSCState):
    #sumarize feedbacks
    prompt = f"Based on the following feedbacks create a summarized feedback, \n Language Feedback: {state['language_feedback']}\n Clarity of thought Feedback: {state['clarity_feedback']}\n Depth of analysis Feedback:{state['analysis_feedback']}"
    overall_feedback = llm_model.invoke(prompt).content
    #avg score calculation
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])
    return {"overall_feedback": overall_feedback, "avg_score": avg_score}

# %%
# create a graph
graph = StateGraph (UPSCState)

#add the nodes
graph.add_node("evaluate_language", evaluate_language)
graph.add_node("evaluate_clarity", evaluate_clarity)
graph.add_node("evaluate_analysis", evaluate_analysis)
graph.add_node("final_evaluation", final_evaluation)

#add the edges
graph.add_edge(START, "evaluate_language")
graph.add_edge(START, "evaluate_clarity")
graph.add_edge(START, "evaluate_analysis")
graph.add_edge("evaluate_language", "final_evaluation")
graph.add_edge("evaluate_clarity", "final_evaluation")
graph.add_edge("evaluate_analysis", "final_evaluation")
graph.add_edge("final_evaluation", END)

#compile the graph
workflow = graph.compile()

# %%
#execute the graph
initial_state = {"essay": essay}
workflow.invoke(initial_state)
# Out:
# {'essay': "Introduction:\n\nIndia is undergoing a remarkable transformation in Artificial Intelligence, driven by the visionary leadership of PM Rodi. For the first time in India's history, the government is actively shaping an Az ecosysten where computing power, GPUs, and research opportunities are accessible at an affordable cost.\n\nUnlike in the past, Al in India is no longer confined to a privileged few or dominated by global tech giants. Through forward-looking policies, the Nodi government is empowering students, startups, and innovators with world-class AI Infrastructure, fostering a truly level playing field. Initiatives such as the IndiaAl Rission and the establishment of Centres of Excellence for Al are strengthening the country's At ecosystem, paving the way for innovation and self-reliance in this critical sector.\n\nThese efforts align with the vision of Viksit Bharet by 2847, where India aspires to become a global Al powerhouse, leveraging cutting-edge technology for e
# ...

# %%
from IPython.display import Image 
Image(workflow.get_graph().draw_mermaid_png())
